# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Lendo Conjunto de dados

# %%
# dados = pd.read_csv('educational_attainment_supplementary_data.csv')
# dados.head()
dados_tab_paises = pd.read_csv('school_and_country_table.csv')
dados_tab_paises.head(11)
# Out:
#                               school_name                   country
# 0                      Harvard University  United States of America
# 1      California Institute of Technology  United States of America
# 2   Massachusetts Institute of Technology  United States of America
# 3                     Stanford University  United States of America
# 4                    Princeton University  United States of America
# 5                 University of Cambridge            United Kingdom
# 6                    University of Oxford            United Kingdom
# 7      University of California, Berkeley  United States of America
# 8                 Imperial College London            United Kingdom
# 9                         Yale University  United States of America
# 10  University of California, Los Angeles  United States of America

# %%
dados_gerais = pd.read_csv('cwurData.csv')

# %% [markdown]
# # Resumo estatístico de campos numéricos

# %%
dados_tab_paises.describe()
# Out:
#                                school_name                   country
# count                                  818                       818
# unique                                 818                        70
# top     Manchester Metropolitan University  United States of America
# freq                                     1                       161

# %% [markdown]
# # Resumo estatístico de campos categoricos

# %%
dados_tab_paises.describe(include='O')
# Out:
#                                school_name                   country
# count                                  818                       818
# unique                                 818                        70
# top     Manchester Metropolitan University  United States of America
# freq                                     1                       161

# %% [markdown]
# # Renomeando colunas

# %%
# Somente visualização
dados_tab_paises.rename({'school_name': 'nome_universidade', 'country': 'país'}, axis=1)
# Out:
#                          nome_universidade                      país
# 0                       Harvard University  United States of America
# 1       California Institute of Technology  United States of America
# 2    Massachusetts Institute of Technology  United States of America
# 3                      Stanford University  United States of America
# 4                     Princeton University  United States of America
# ..                                     ...                       ...
# 813                      Xidian University                     China
# 814                    Yeungnam University               South Korea
# 815            Yıldız Technical University                    Turkey
# 816               Yokohama City University                     Japan
# 817           Yokohama National University                     Japan
#
# [818 rows x 2 columns]

# %%
# Em definitivo - usando 'inplace'
dados_tab_paises.rename({'school_name': 'nome_universidade', 'country': 'país'}, axis=1, inplace=True)

# %%
dados_tab_paises
# Out:
#                          nome_universidade                      país
# 0                       Harvard University  United States of America
# 1       California Institute of Technology  United States of America
# 2    Massachusetts Institute of Technology  United States of America
# 3                      Stanford University  United States of America
# 4                     Princeton University  United States of America
# ..                                     ...                       ...
# 813                      Xidian University                     China
# 814                    Yeungnam University               South Korea
# 815            Yıldız Technical University                    Turkey
# 816               Yokohama City University                     Japan
# 817           Yokohama National University                     Japan
#
# [818 rows x 2 columns]

# %%
# Data Frame com 30 primeiros nomes de universidades organizadas por indices
dados_tab_paises[['nome_universidade']].head(31)
# Out:
#                                     nome_universidade
# 0                                  Harvard University
# 1                  California Institute of Technology
# 2               Massachusetts Institute of Technology
# 3                                 Stanford University
# 4                                Princeton University
# 5                             University of Cambridge
# 6                                University of Oxford
# 7                  University of California, Berkeley
# 8                             Imperial College London
# 9                                     Yale University
# 10              University of California, Los Angeles
# 11                              University of Chicago
# 12                           Johns Hopkins University
# 13                                 Cornell University
# 14  ETH Zurich – Swiss Federal Institute of Techno...
# 15                             University of Michigan
# ...

# %%
# Data Frame com 30 primeiros países organizados por indices
dados_tab_paises[['país']].head(31)
# Out:
#                         país
# 0   United States of America
# 1   United States of America
# 2   United States of America
# 3   United States of America
# 4   United States of America
# 5             United Kingdom
# 6             United Kingdom
# 7   United States of America
# 8             United Kingdom
# 9   United States of America
# 10  United States of America
# 11  United States of America
# 12  United States of America
# 13  United States of America
# 14               Switzerland
# 15  United States of America
# 16                    Canada
# 17  United States of America
# 18  United States of America
# 19  United States of America
# 20                 Hong Kong
# 21            United Kingdom
# 22  United States of America
# 23  United States of America
# 24  United States of America
# 25                     Japan
# 26  United States of America
# 27               South Korea
# 28  United States of America
# 29                    Canada
# 30  United States of America

# %%
# Contagem de todos os dados das duas tabelas do conjunto de dados
dados_tab_paises.count()
# Out:
# nome_universidade    818
# país                 818
# dtype: int64

# %% [markdown]
# # Leitura do conjunto de dados organizados por país, série e ano

# %%
dados
# Out:
#                                             country_name  \
# 0                                            Afghanistan
# 1                                            Afghanistan
# 2                                            Afghanistan
# 3                                            Afghanistan
# 4                                            Afghanistan
# ...                                                  ...
# 79050                                                NaN
# 79051                                                NaN
# 79052                                                NaN
# 79053  Data from database: Education Statistics: Educ...
# 79054                           Last Updated: 10/20/2015
#
#                                              series_name  1985  1986  1987  \
# 0      Barro-Lee: Average years of primary schooling,...  0.33   NaN   NaN
# 1      Barro-Lee: Average years of primary schooling,...  1.03   NaN   NaN
# ...

# %%
dados.head(21)
# Out:
#    country_name                                        series_name  1985  \
# 0   Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33
# 1   Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03
# 2   Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83
# 3   Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34
# 4   Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54
# 5   Afghanistan  Barro-Lee: Average years of primary schooling,...  1.52
# 6   Afghanistan  Barro-Lee: Average years of primary schooling,...  0.17
# 7   Afghanistan  Barro-Lee: Average years of primary schooling,...  0.66
# 8   Afghanistan  Barro-Lee: Average years of primary schooling,...  0.44
# 9   Afghanistan  Barro-Lee: Average years of primary schooling,...  1.28
# 10  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.22
# 11  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.95
# ...

# %% [markdown]
# # Ranking das universidades (Dados gerais)

# %%
dados_gerais
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
# Ranking das 30 melhores universidades 
dados_gerais.head(30)
# Out:
#     world_rank                                      institution  \
# 0            1                               Harvard University
# 1            2            Massachusetts Institute of Technology
# 2            3                              Stanford University
# 3            4                          University of Cambridge
# 4            5               California Institute of Technology
# 5            6                             Princeton University
# 6            7                             University of Oxford
# 7            8                                  Yale University
# 8            9                              Columbia University
# 9           10               University of California, Berkeley
# 10          11                            University of Chicago
# 11          12                               Cornell University
# 12          13                       University of Pennsylvania
# 13          14                              University of Tokyo
# ...

# %% [markdown]
# # Renomeando colunas

# %%
dados_gerais.rename({'world_rank': 'rank_mundial','institution':'instituicao','country': 'país', 'national_rank':'rank_nacional','quality_of_education':'qualidade_educacao','alumni_employment':'alunos_empregados','quality_of_faculty': 'qualidade_fac'},axis=1, inplace=True)

# %%
dados_gerais
# Out:
#       rank_mundial                            instituicao            país  \
# 0                1                     Harvard University             USA
# 1                2  Massachusetts Institute of Technology             USA
# 2                3                    Stanford University             USA
# 3                4                University of Cambridge  United Kingdom
# 4                5     California Institute of Technology             USA
# ...            ...                                    ...             ...
# 2195           996              University of the Algarve        Portugal
# 2196           997                  Alexandria University           Egypt
# 2197           998            Federal University of Ceará          Brazil
# 2198           999                 University of A Coruña           Spain
# 2199          1000        China Pharmaceutical University           China
#
#       rank_nacional  qualidade_educacao  alunos_empregados  qualidade_fac  \
# ...

# %%
dados_gerais.rename({'publications':'publicacoes','influence': 'influencia','citations':'citacoes','broad_impact':'impacto_geral','patents':'patentes','year':'ano'}, axis=1, inplace=True)

# %%
dados_gerais
# Out:
#       rank_mundial                            instituicao            país  \
# 0                1                     Harvard University             USA
# 1                2  Massachusetts Institute of Technology             USA
# 2                3                    Stanford University             USA
# 3                4                University of Cambridge  United Kingdom
# 4                5     California Institute of Technology             USA
# ...            ...                                    ...             ...
# 2195           996              University of the Algarve        Portugal
# 2196           997                  Alexandria University           Egypt
# 2197           998            Federal University of Ceará          Brazil
# 2198           999                 University of A Coruña           Spain
# 2199          1000        China Pharmaceutical University           China
#
#       rank_nacional  qualidade_educacao  alunos_empregados  qualidade_fac  \
# ...

# %%
#  As 10 melhores universidades do Mundo segundo conjunto de dados dados_gerais
dados_gerais[['rank_mundial','instituicao', 'país']].head(10)
# Out:
#    rank_mundial                            instituicao            país
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5     California Institute of Technology             USA
# 5             6                   Princeton University             USA
# 6             7                   University of Oxford  United Kingdom
# 7             8                        Yale University             USA
# 8             9                    Columbia University             USA
# 9            10     University of California, Berkeley             USA

# %%
# Qualidade da educação das 10 melhores universidades do Mundo
dados_gerais[['qualidade_educacao','instituicao','país']].sort_values('qualidade_educacao',ascending=True).head(10)
# Out:
#       qualidade_educacao                            instituicao  \
# 20                     1                 Rockefeller University
# 1200                   1                     Harvard University
# 200                    1                     Harvard University
# 100                    1                     Harvard University
# 103                    2  Massachusetts Institute of Technology
# 4                      2     California Institute of Technology
# 1203                   2                University of Cambridge
# 203                    2                University of Cambridge
# 53                     3       École normale supérieure - Paris
# 104                    3                University of Cambridge
#
#                 país
# 20               USA
# 1200             USA
# 200              USA
# 100              USA
# 103              USA
# 4                USA
# 1203  United Kingdom
# 203   United Kingdom
# 53            France
# 104   United Kingdom

# %%
# Para visualizar somente as universidades dos Estados Unidos
dados_gerais[['instituicao','país']].loc[dados_gerais['país'] == 'USA']
# Out:
#                                 instituicao país
# 0                        Harvard University  USA
# 1     Massachusetts Institute of Technology  USA
# 2                       Stanford University  USA
# 4        California Institute of Technology  USA
# 5                      Princeton University  USA
# ...                                     ...  ...
# 2100     University of Southern Mississippi  USA
# 2105                     Oakland University  USA
# 2112             University of North Dakota  USA
# 2128         University of Texas at El Paso  USA
# 2135       University of California, Merced  USA
#
# [573 rows x 2 columns]

# %%
# Para saber quantas universidades são Norte-americanas
dados_gerais[['instituicao','país']].loc[dados_gerais['país']== 'EUA'].count()
# Out:
# instituicao    573
# país           573
# dtype: int64

# %%
# Para saber quantas instituicões são brasileiras
dados_gerais[['instituicao','país']].loc[dados_gerais['país']== 'Brasil'].count()
# Out:
# instituicao    36
# país           36
# dtype: int64

# %%
# Para saber quantas instituições são francesas
dados_gerais[['instituicao','país']].loc[dados_gerais['país']=='França'].count()
# Out:
# instituicao    109
# país           109
# dtype: int64

# %%
# Qual a universidade que tem os piores scores
dados_gerais[['instituicao', 'país']].loc[dados_gerais['score']== 44.02]
# Out:
#                           instituicao   país
# 2198           University of A Coruña  Spain
# 2199  China Pharmaceutical University  China

# %%
# Qual a universidade com o melhor score
dados_gerais[['instituicao', 'país']].loc[dados_gerais['score']==100.00]
# Out:
#              instituicao país
# 0     Harvard University  USA
# 100   Harvard University  USA
# 200   Harvard University  USA
# 1200  Harvard University  USA

# %%
# Universidade com o maior número de patentes
dados_gerais[['instituicao','país','patentes']].sort_values('patentes', ascending=False)
# Out:
#                                          instituicao            país  patentes
# 1478                      London School of Economics  United Kingdom       871
# 2046  King Fahd University of Petroleum and Minerals    Saudi Arabia       871
# 2068                             Makerere University          Uganda       871
# 2066            University of the Republic (Uruguay)         Uruguay       871
# 2064                 National Chung Cheng University          Taiwan       871
# ...                                              ...             ...       ...
# 54                             University of Florida             USA         2
# 1202           Massachusetts Institute of Technology             USA         1
# 1              Massachusetts Institute of Technology             USA         1
# 202            Massachusetts Institute of Technology             USA         1
# 103            Massachusetts Institute of Technology             USA         1
#
# [2200 rows x 3 columns]

# %%
dados_gerais[['instituicao','país','patentes']].loc[1478]
# Out:
# instituicao    London School of Economics
# país                       United Kingdom
# patentes                              871
# Name: 1478, dtype: object

# %%
# Universidade com o menor número de patentes registradas
dados_gerais[['instituicao','país','patentes']].sort_values('patentes', ascending=True)
# Out:
#                                      instituicao    país  patentes
# 1          Massachusetts Institute of Technology     EUA         1
# 103        Massachusetts Institute of Technology     EUA         1
# 202        Massachusetts Institute of Technology     EUA         1
# 1202       Massachusetts Institute of Technology     EUA         1
# 200                           Harvard University     EUA         2
# ...                                          ...     ...       ...
# 1949            University of Évry Val d'Essonne  França       871
# 2104                      University of Thessaly  Grécia       871
# 2105                          Oakland University     EUA       871
# 1954  National Research Nuclear University MEPhI  Russia       871
# 1927    Kyoto Prefectural University of Medicine   Japão       871
#
# [2200 rows x 3 columns]

# %% [markdown]
# # Renomeando alguns nomes de países das colunas

# %%
dados_gerais['país'].replace(['Brazil', 'USA', 'France','Spain','Egypt','United Kingdom','Greece','Japan','Uruguay','Saudi Arabia'],['Brasil','EUA', 'França','Espanha',
                                'Egito','Reino Unido','Grécia','Japão','Uruguai','Arábia Saudita'], inplace=True)

# %%
dados_gerais['país'].replace('Switzerland', 'Suiça', inplace=True)

# %%
dados_gerais['país'].replace(['Sweden','Denmark', 'Poland'], ['Suécia','Dinamarca','Polônia'], inplace=True)

# %%
dados_gerais['país'].replace('Finland', 'Finlândia', inplace=True)

# %%
dados_gerais[['instituicao','país']].head(30)
# Out:
#                                         instituicao         país
# 0                                Harvard University          EUA
# 1             Massachusetts Institute of Technology          EUA
# 2                               Stanford University          EUA
# 3                           University of Cambridge  Reino Unido
# 4                California Institute of Technology          EUA
# 5                              Princeton University          EUA
# 6                              University of Oxford  Reino Unido
# 7                                   Yale University          EUA
# 8                               Columbia University          EUA
# 9                University of California, Berkeley          EUA
# 10                            University of Chicago          EUA
# 11                               Cornell University          EUA
# 12                       University of Pennsylvania          EUA
# ...

# %% [markdown]
# # Agrupar por...

# %%
# Agrupando pela soma das instituições e países
dados_gerais.groupby(['instituicao','país']).sum()
# Out:
#                                                       rank_mundial  \
# instituicao                              país
# AGH University of Science and Technology Polônia              1435
# Aalborg University                       Dinamarca            1158
# Aalto University                         Finlândia             813
# Aarhus University                        Dinamarca             241
# Aberystwyth University                   Reino Unido          1614
# ...                                                            ...
# École centrale de Lyon                   França                881
# École normale supérieure - Paris         França                190
# École normale supérieure de Cachan       França                721
# École normale supérieure de Lyon         França                933
# Örebro University                        Suécia               1295
#
#                                                       rank_nacional  \
# ...

# %% [markdown]
# # Cruzando informações das tabelas

# %%
pd.crosstab(dados_gerais['país'],dados_gerais['qualidade_educacao'],margins=True).tail(5).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_71000fcc_5064_11eb_8d86_e0d55ef1ed09row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_71000fcc_5064_11eb_8d86_e0d55ef1ed09row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_71000fcc_5064_11eb_8d86_e0d55ef1ed09row0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_71000fcc_5064_11eb_8d86_e0d55ef1ed09row0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_71000fcc_5064_11eb_8d86_e0d55ef1ed09row0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_71000fcc_5064_11eb_8d86_e0d55ef1ed09row0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_71000fcc_5064_11eb_8d86_e0d55ef1ed09row0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...
